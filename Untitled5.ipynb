# %%
# %pip install tensorflow
# Out:
# ...
#
#   Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.12.23-py2.py3-none-any.whl.metadata (876 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached grpcio-1.68.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# ...
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached keras-3.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...

# %%
import tensorflow as tf
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from tensorflow.python.keras.models import sequential

# %%
from tensorflow.python.keras.layers import Conc2D,MaxPool2D,Flatten,Dropout,Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from tensorflow.python.keras.layers import Conc2D,MaxPool2D,Flatten,Dropout,Dense
#
# ImportError: cannot import name 'Conc2D' from 'tensorflow.python.keras.layers' (C:\Users\lenovo\anaconda3\Lib\site-packages\tensorflow\python\keras\layers\__init__.py)

# %%
import matplotlib.pyplot as plt

# %%
from keras.detasets import cifar10

# %%
(train_im,train_lab),(test_img,test_lab) = cifar10.load_data()

# %%
class_names= ["airplane","automobile","bird","cat","deer","dog"]

# %%
plt.figure(figsize=(10,10))

# %%
import matplotlib.pyplot as plt

# Assuming 'train_img' and 'train_lab' are already defined and 'class_names' is a list of class labels.

# Create a 3x3 grid for displaying the images
plt.figure(figsize=(10, 10))  # Set the figure size for better clarity

for i in range(9):  # Loop through the first 9 images
    plt.subplot(3, 3, i + 1)  # Create a subplot at position i+1 in a 3x3 grid
    plt.imshow(train_img[i])  # Display the image
    plt.xticks([])  # Remove x-axis ticks
    plt.yticks([])  # Remove y-axis ticks
    plt.grid(False)  # Disable grid lines
    plt.xlabel(class_names[train_lab[i][0]])  # Label the image with the class name

plt.show()  # Display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 10
#       8 for i in range(9):  # Loop through the first 9 images
#       9     plt.subplot(3, 3, i + 1)  # Create a subplot at position i+1 in a 3x3 grid
# ---> 10     plt.imshow(train_img[i])  # Display the image
#      11     plt.xticks([])  # Remove x-axis ticks
#      12     plt.yticks([])  # Remove y-axis ticks
#
# NameError: name 'train_img' is not defined

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

# %%
# Import necessary modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the model
model = Sequential()

# Add layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))  # Assuming 10 classes in the output layer

# Print model summary to check the architecture
model.summary()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'
])

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset (you can replace this with your own dataset)
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
# Reshaping the data to add the channel dimension (for grayscale, it's 1)
X_train = X_train.reshape(-1, 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)  # 10 classes for MNIST
y_test = to_categorical(y_test, 10)

# Define the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))  # 10 output classes for MNIST

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 8s 1us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 60s 30ms/step - accuracy: 0.9105 - loss: 0.3000
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 60s 32ms/step - accuracy: 0.9834 - loss: 0.0540
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 30ms/step - accuracy: 0.9919 - loss: 0.0282
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 30ms/step - accuracy: 0.9943 - loss: 0.0192
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 60s 32ms/step - accuracy: 0.9964 - loss: 0.0120
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 58s 31ms/step - accuracy: 0.9969 - loss: 0.0097
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 30ms/step - accuracy: 0.9973 - loss: 0.0083
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 61s 32ms/step - accuracy: 0.9987 - loss: 0.0043
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 58s 31ms/step - accuracy: 0.9991 - loss: 0.0036
# Epoch 10/10
#  487/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - accuracy: 0.9986 - loss: 0.0036
